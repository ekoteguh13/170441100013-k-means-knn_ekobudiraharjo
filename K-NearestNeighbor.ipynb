# %%
### Import librari terlebih dahulu
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

### Memanggil file csv dengan librari pandas
data_orj = pd.read_csv("go_track_tracks.csv")

### Mengambil semua data untuk percobaan
data = data_orj.loc [:,'id':'car_or_bus']

### Mengambil 3 kolom
data_knn = data[['rating_bus','car_or_bus','rating_weather']]

### Input jumlah K atau jumlah tetangga terdekat
inK = int(input("Masukkan K : "))

### Mencari knn dengan menggunakan sklearn neighbors clssifier
knn = KNeighborsClassifier(n_neighbors = inK)  
x,y = data_knn.loc[:,data_knn.columns != 'car_or_bus'], data_knn.loc[:,'car_or_bus']
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.3, random_state = 42)
knn.fit(x_train,y_train)
prediction = knn.predict(x_test)

print('KNN dengan (K =',inK,') Akurasinya adalah: ', knn.score(x_test,y_test))
print("")

datatest = pd.DataFrame(x_test)
datatest["car_or_bus"] = y_test
datatest["prediksi"] = prediction
print ("Data Asli dan Prediksinya")
print (datatest)
# Out:
# Masukkan K : 4
# KNN dengan (K = 4 ) Akurasinya adalah:  0.7755102040816326
#
# Data Asli dan Prediksinya
#      rating_bus  rating_weather  car_or_bus  prediksi
# 135           3               1           2         2
# 115           1               1           2         2
# 131           0               0           1         1
# 55            0               0           2         1
# 95            1               2           2         2
# 29            0               0           1         1
# 156           0               0           1         1
# 51            0               0           2         1
# 101           1               2           2         2
# 145           1               2           2         2
# 19            0               0           2         1
# 85            1               1           2         2
# 15            0               0           1         1
# 66            0               0           1         1
# 24            0               0           1         1
# 30            0               0           1         1
# 132           0               0           1         1
# 105           0               0           1         1
# 151           0               0           1         1
# 16            0               0           1         1
# 75            0               0           1         1
# 18            0               0           2         1
# 12            0               0           2         1
# 9             0               0           2         1
# 31            0               0           1         1
# 154           0               0           1         1
# 98            1               2           2         2
# 56            0               0           2         1
# 134           2               2           2         2
# 159           0               0           1         1
# 139           0               0           1         1
# 78            0               0           2         1
# 60            0               0           1         1
# 84            0               0           1         1
# 2             0               0           2         1
# 94            2               2           2         2
# 45            0               0           1         1
# 42            0               0           2         1
# 69            0               0           1         1
# 152           0               0           1         1
# 26            0               0           1         1
# 141           2               2           2         2
# 117           1               2           2         2
# 93            0               0           1         1
# 133           0               0           1         1
# 36            0               0           1         1
# 82            0               0           2         1
# 22            0               0           1         1
# 126           0               0           1         1
